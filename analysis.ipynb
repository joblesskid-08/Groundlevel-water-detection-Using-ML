# %%
	
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('cleaned_file.csv')

# %% [markdown]
#
# Now defining the features variables (using the pre & post moonsoon data from 2015 to 2021 )

# %%
features = df[['Pre-monsoon_2015 (meters below ground level)', 'Post-monsoon_2015 (meters below ground level)', 'Pre-monsoon_2016 (meters below ground level)', 'Post-monsoon_2016 (meters below ground level)', 'Pre-monsoon_2017 (meters below ground level)', 'Post-monsoon_2017 (meters below ground level)', 'Pre-monsoon_2018 (meters below ground level)', 'Post-monsoon_2018 (meters below ground level)', 'Pre-monsoon_2019 (meters below ground level)', 'Post-monsoon_2019 (meters below ground level)', 'Pre-monsoon_2020 (meters below ground level)', 'Post-monsoon_2020 (meters below ground level)', 'Pre-monsoon_2021 (meters below ground level)', 'Post-monsoon_2021 (meters below ground level)']]

# %% [markdown]
# Defining the target variables. (predicting the pre & post moonsoon data from 2022)

# %%
target = df[['Pre-monsoon_2022 (meters below ground level)', 'Post-monsoon_2022 (meters below ground level)']]

# %% [markdown]
# Splitting the data into training and testing data.

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)
#Currently using 70-30 split
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluation of the model

# %%
score = model.score(X_test, y_test)

print(f'The model score is {score}')
# Out:
# The model score is 0.9541545024900656

# %% [markdown]
# Graphical representation of the model

# %%
predictions = model.predict(X_test)
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values for Pre-monsoon and Post-monsoon 2022')
limits = [np.min([plt.xlim(), plt.ylim()]),
          np.max([plt.xlim(), plt.ylim()])]
plt.plot(limits, limits, color='red')  # plot the y = x line

plt.savefig('actual_vs_predicted.png')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.metrics import r2_score
from sklearn.multioutput import MultiOutputRegressor

from sklearn.metrics import mean_squared_log_error, median_absolute_error, explained_variance_score, max_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


import pandas as pd

# Read the csv file
df2 = pd.read_csv(r'C:\Users\visha\Downloads\sih-main\merged.csv')
df = pd.read_csv(r'modified_file2.csv')

# %% [markdown]
# Performing Exploratory Data Analysis(EDA)

# %%
months = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']

corelation_pre = [df['Post-monsoon_2022 (meters below ground level)'].corr(df[month]) for month in months]
corelation_post = [df['Pre-monsoon_2022 (meters below ground level)'].corr(df[month]) for month in months]

x = range(len(months))

plt.figure(figsize=(12, 6))

plt.bar(x, corelation_pre, width=0.4, label='Pre-monsoon', color='b', align='center')
plt.bar(x, corelation_post, width=0.4, label='Post-monsoon', color='r', align='edge')

plt.xlabel('Months')
plt.ylabel('Correlation')
plt.title('Correlation between each month of rainfall and the pre-monsoon post-monsoon level')
plt.xticks(x, months, rotation='vertical')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Now defining the features variables (using the pre & post moonsoon data from 2015 to 2021 )

# %%
features1 = df[['Pre-monsoon_2015 (meters below ground level)', 'Post-monsoon_2015 (meters below ground level)', 'Pre-monsoon_2016 (meters below ground level)', 'Post-monsoon_2016 (meters below ground level)', 'Pre-monsoon_2017 (meters below ground level)', 'Post-monsoon_2017 (meters below ground level)', 'Pre-monsoon_2018 (meters below ground level)', 'Post-monsoon_2018 (meters below ground level)', 'Pre-monsoon_2019 (meters below ground level)', 'Post-monsoon_2019 (meters below ground level)', 'Pre-monsoon_2020 (meters below ground level)', 'Post-monsoon_2020 (meters below ground level)', 'Pre-monsoon_2021 (meters below ground level)', 'Post-monsoon_2021 (meters below ground level)', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec' ]]
aquifer_encoded = pd.get_dummies(df['Aquifer'])

# Concatenate the one-hot encoded dataframe with the original features dataframe
features = pd.concat([features1, aquifer_encoded], axis=1)

# %% [markdown]
# Defining the target variables. (predicting the pre & post moonsoon data from 2022)

# %%
target = df[['Pre-monsoon_2022 (meters below ground level)', 'Post-monsoon_2022 (meters below ground level)']]

# %% [markdown]
# Splitting the data into training and testing datasets.

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
#Currently using 50/50 split
model = MultiOutputRegressor(GradientBoostingRegressor(random_state=0))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(random_state=0))

# %% [markdown]
# Evaluation of the model

# %%
y_pred = model.predict(X_test)
score = r2_score(y_test, y_pred)

print(f'The model score is {score}')
# Out:
# The model score is 0.9783020357113112

# %% [markdown]
# now using random-forest.

# %%
model_rf = MultiOutputRegressor(RandomForestRegressor(random_state=0))

# Fit the model
model_rf.fit(X_train, y_train)

# Predict the test set results
y_pred_rf = model_rf.predict(X_test)

# Calculate the R2 score
score_rf = r2_score(y_test, y_pred_rf)

# %% [markdown]
# Evaluating random forest model.

# %%
print(f'The Random Forest model score is {score_rf}')
# Out:
# The Random Forest model score is 0.9794926404875631

# %% [markdown]
# Graphing the models comparitively

# %%
models = ['Gradient Boosting', 'Random Forest']

# Corresponding scores
scores = [score, score_rf]

plt.bar(models, scores, color=['blue', 'green'])
plt.xlabel('Models')
plt.ylabel('R2 Score')
plt.title('Comparison of Model Performance (R-squared score)')
plt.show()

# %% [markdown]
# Now comparing on other matrices.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Calculate metrics for Gradient Boosting
mae_gb = mean_absolute_error(y_test, y_pred)
mse_gb = mean_squared_error(y_test, y_pred)
rmse_gb = np.sqrt(mse_gb)

# Calculate metrics for Random Forest
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)

# Define the models and their corresponding metrics
models = ['Gradient Boosting', 'Random Forest']
mae_scores = [mae_gb, mae_rf]
mse_scores = [mse_gb, mse_rf]
rmse_scores = [rmse_gb, rmse_rf]


# Calculate additional metrics for Gradient Boosting
medae_gb = median_absolute_error(y_test, y_pred)
evs_gb = explained_variance_score(y_test, y_pred)

# Calculate additional metrics for Random Forest
medae_rf = median_absolute_error(y_test, y_pred_rf)
evs_rf = explained_variance_score(y_test, y_pred_rf)

# Print all metrics for both models
print("Gradient Boosting Metrics:")
print(f"MAE: {mae_gb}, MSE: {mse_gb}, RMSE: {rmse_gb}, MedAE: {medae_gb}, EVS: {evs_gb}\n")

print("Random Forest Metrics:")
print(f"MAE: {mae_rf}, MSE: {mse_rf}, RMSE: {rmse_rf}, MedAE: {medae_rf}, EVS: {evs_rf}\n")
# Out:
# Gradient Boosting Metrics:
# MAE: 1.9411232584322748, MSE: 12.11825652164185, RMSE: 3.481128627563459, MedAE: 1.1520591939886218, EVS: 0.9783441469587069
#
# Random Forest Metrics:
# MAE: 1.868200000000001, MSE: 11.376646612750005, RMSE: 3.3729284920896268, MedAE: 1.0556500000000049, EVS: 0.9795648688446411

# %% [markdown]
# Now using a neural Network.
# We are using neural network from tensorflow.

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential

# %% [markdown]
# For simplicity, let's create a model with one hidden layer. The input and output layer sizes should match the number of features and the number of output variables, respectively.

# %%
from tensorflow.keras.losses import Huber
model = Sequential()
model.add(Input(shape=(len(X_train.columns),)))  # Input layer
model.add(Dense(32, activation='relu'))# Hidden layer
model.add(Dense(32, activation='relu'))# Hidden layer
model.add(Dense(2))  # Output layer
model.compile(loss='huber', optimizer='adam')
# Train the model on the training data
history = model.fit(X_train, y_train, epochs=500, validation_data=(X_test, y_test))
print(f"Shape of X_test: {X_test.shape}")
# Out:
# Epoch 1/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 19.5327 - val_loss: 4.9330
# Epoch 2/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3568 - val_loss: 3.8345
# Epoch 3/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5814 - val_loss: 3.8366
# Epoch 4/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2698 - val_loss: 2.8808
# Epoch 5/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8474 - val_loss: 2.7121
# Epoch 6/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6237 - val_loss: 2.8587
# Epoch 7/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7820 - val_loss: 2.6092
# Epoch 8/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6436 - val_loss: 2.4783
# Epoch 9/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5168 - val_loss: 2.6272
# Epoch 10/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4098 - val_loss: 2.4986
# Epoch 11/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3609 - val_loss: 3.0452
# Epoch 12/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6441 - val_loss: 2.3812
# Epoch 13/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3045 - val_loss: 2.2030
# Epoch 14/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3095 - val_loss: 2.1256
# Epoch 15/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2629 - val_loss: 2.0152
# Epoch 16/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1614 - val_loss: 1.9456
# Epoch 17/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1398 - val_loss: 2.0547
# Epoch 18/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2662 - val_loss: 2.1197
# Epoch 19/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0142 - val_loss: 1.8431
# Epoch 20/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9919 - val_loss: 2.0854
# Epoch 21/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2607 - val_loss: 1.7538
# Epoch 22/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9305 - val_loss: 1.9287
# Epoch 23/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8773 - val_loss: 1.7896
# Epoch 24/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9793 - val_loss: 1.9601
# Epoch 25/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9816 - val_loss: 1.6954
# Epoch 26/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8335 - val_loss: 1.8213
# Epoch 27/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6479 - val_loss: 1.8449
# Epoch 28/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8241 - val_loss: 1.7956
# Epoch 29/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9559 - val_loss: 2.0237
# Epoch 30/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9626 - val_loss: 1.8164
# Epoch 31/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3072 - val_loss: 1.6978
# Epoch 32/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9665 - val_loss: 1.6688
# Epoch 33/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1395 - val_loss: 1.6107
# Epoch 34/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9391 - val_loss: 1.6538
# Epoch 35/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8595 - val_loss: 1.5558
# Epoch 36/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6402 - val_loss: 2.1088
# Epoch 37/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1369 - val_loss: 1.6447
# Epoch 38/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8117 - val_loss: 1.4895
# Epoch 39/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7507 - val_loss: 1.5446
# Epoch 40/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7427 - val_loss: 1.5358
# Epoch 41/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8614 - val_loss: 1.6076
# Epoch 42/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6508 - val_loss: 2.2174
# Epoch 43/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9316 - val_loss: 1.5399
# Epoch 44/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6961 - val_loss: 1.7005
# Epoch 45/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7836 - val_loss: 1.5734
# Epoch 46/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8405 - val_loss: 1.6839
# Epoch 47/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7922 - val_loss: 1.5880
# Epoch 48/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8296 - val_loss: 1.6965
# Epoch 49/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6855 - val_loss: 1.5428
# Epoch 50/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9776 - val_loss: 1.6622
# Epoch 51/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7638 - val_loss: 1.5746
# Epoch 52/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7802 - val_loss: 1.5710
# Epoch 53/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7712 - val_loss: 1.6963
# Epoch 54/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7395 - val_loss: 1.6061
# Epoch 55/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6243 - val_loss: 1.6100
# Epoch 56/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7503 - val_loss: 1.5763
# Epoch 57/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8678 - val_loss: 1.6761
# Epoch 58/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9233 - val_loss: 1.6557
# Epoch 59/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7816 - val_loss: 1.8400
# Epoch 60/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7894 - val_loss: 1.6077
# Epoch 61/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7000 - val_loss: 1.6053
# Epoch 62/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6650 - val_loss: 1.5795
# Epoch 63/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8939 - val_loss: 1.7112
# Epoch 64/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6461 - val_loss: 1.6639
# Epoch 65/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5475 - val_loss: 1.5668
# Epoch 66/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8437 - val_loss: 1.5466
# Epoch 67/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5458 - val_loss: 1.8299
# Epoch 68/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5911 - val_loss: 1.7493
# Epoch 69/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8913 - val_loss: 1.4719
# Epoch 70/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5711 - val_loss: 1.6925
# Epoch 71/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6127 - val_loss: 1.5883
# Epoch 72/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6124 - val_loss: 1.5992
# Epoch 73/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8423 - val_loss: 1.5872
# Epoch 74/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5569 - val_loss: 1.5148
# Epoch 75/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4912 - val_loss: 1.5867
# Epoch 76/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7441 - val_loss: 1.6307
# Epoch 77/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2010 - val_loss: 1.6401
# Epoch 78/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6268 - val_loss: 1.7769
# Epoch 79/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6576 - val_loss: 1.6970
# Epoch 80/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6555 - val_loss: 1.6483
# Epoch 81/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5498 - val_loss: 1.9142
# Epoch 82/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7962 - val_loss: 1.5157
# Epoch 83/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6483 - val_loss: 1.5811
# Epoch 84/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6716 - val_loss: 1.6467
# Epoch 85/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5132 - val_loss: 1.4965
# Epoch 86/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6919 - val_loss: 2.0767
# Epoch 87/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6602 - val_loss: 1.5078
# Epoch 88/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5930 - val_loss: 1.4574
# Epoch 89/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6167 - val_loss: 1.5376
# Epoch 90/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7096 - val_loss: 1.7732
# Epoch 91/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5720 - val_loss: 1.5955
# Epoch 92/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6204 - val_loss: 1.7649
# Epoch 93/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4861 - val_loss: 1.4277
# Epoch 94/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4626 - val_loss: 1.6882
# Epoch 95/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6617 - val_loss: 1.4799
# Epoch 96/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7536 - val_loss: 1.5262
# Epoch 97/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7500 - val_loss: 1.4968
# Epoch 98/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6133 - val_loss: 1.5164
# Epoch 99/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8253 - val_loss: 1.5012
# Epoch 100/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5393 - val_loss: 1.9636
# Epoch 101/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8107 - val_loss: 1.5634
# Epoch 102/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5627 - val_loss: 1.4579
# Epoch 103/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5562 - val_loss: 1.4590
# Epoch 104/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8140 - val_loss: 1.5595
# Epoch 105/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7685 - val_loss: 1.6037
# Epoch 106/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5805 - val_loss: 1.4408
# Epoch 107/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5283 - val_loss: 1.4134
# Epoch 108/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3948 - val_loss: 1.7790
# Epoch 109/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6168 - val_loss: 1.8587
# Epoch 110/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8607 - val_loss: 1.5531
# Epoch 111/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6186 - val_loss: 1.4378
# Epoch 112/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5823 - val_loss: 1.5524
# Epoch 113/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4923 - val_loss: 1.3926
# Epoch 114/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5292 - val_loss: 1.5160
# Epoch 115/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4593 - val_loss: 1.5004
# Epoch 116/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4527 - val_loss: 1.4842
# Epoch 117/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4957 - val_loss: 1.4693
# Epoch 118/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5182 - val_loss: 1.4420
# Epoch 119/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5164 - val_loss: 1.6514
# Epoch 120/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7450 - val_loss: 1.4686
# Epoch 121/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4284 - val_loss: 1.4579
# Epoch 122/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5810 - val_loss: 1.4738
# Epoch 123/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4847 - val_loss: 1.5856
# Epoch 124/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6290 - val_loss: 1.6283
# Epoch 125/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5231 - val_loss: 1.7542
# Epoch 126/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5791 - val_loss: 1.5256
# Epoch 127/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6498 - val_loss: 1.4620
# Epoch 128/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4695 - val_loss: 1.5042
# Epoch 129/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5080 - val_loss: 1.5224
# Epoch 130/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8430 - val_loss: 1.8182
# Epoch 131/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6921 - val_loss: 1.5817
# Epoch 132/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5612 - val_loss: 1.4857
# Epoch 133/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7300 - val_loss: 1.5414
# Epoch 134/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6779 - val_loss: 1.6034
# Epoch 135/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4045 - val_loss: 1.4937
# Epoch 136/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5265 - val_loss: 1.6340
# Epoch 137/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6147 - val_loss: 1.5415
# Epoch 138/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5525 - val_loss: 1.4023
# Epoch 139/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6383 - val_loss: 1.4239
# Epoch 140/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5890 - val_loss: 1.6658
# Epoch 141/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6304 - val_loss: 1.3928
# Epoch 142/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6876 - val_loss: 1.5149
# Epoch 143/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5258 - val_loss: 1.4697
# Epoch 144/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4794 - val_loss: 1.4164
# Epoch 145/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5731 - val_loss: 1.6803
# Epoch 146/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5184 - val_loss: 1.5001
# Epoch 147/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5376 - val_loss: 1.4372
# Epoch 148/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4057 - val_loss: 1.5588
# Epoch 149/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5519 - val_loss: 1.4738
# Epoch 150/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4695 - val_loss: 1.4088
# Epoch 151/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6016 - val_loss: 1.4885
# Epoch 152/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5422 - val_loss: 1.5205
# Epoch 153/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8122 - val_loss: 1.4803
# Epoch 154/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5258 - val_loss: 1.4739
# Epoch 155/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6519 - val_loss: 1.4632
# Epoch 156/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4949 - val_loss: 1.5630
# Epoch 157/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4664 - val_loss: 2.0257
# Epoch 158/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7826 - val_loss: 1.5834
# Epoch 159/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6745 - val_loss: 1.4632
# Epoch 160/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6208 - val_loss: 1.6090
# Epoch 161/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4458 - val_loss: 1.5154
# Epoch 162/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8605 - val_loss: 1.5537
# Epoch 163/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5875 - val_loss: 1.4679
# Epoch 164/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7510 - val_loss: 1.5065
# Epoch 165/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5369 - val_loss: 1.5152
# Epoch 166/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5320 - val_loss: 1.4666
# Epoch 167/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5074 - val_loss: 1.4742
# Epoch 168/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4526 - val_loss: 1.4939
# Epoch 169/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5008 - val_loss: 1.4633
# Epoch 170/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6039 - val_loss: 1.4820
# Epoch 171/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5063 - val_loss: 1.5706
# Epoch 172/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5408 - val_loss: 1.4347
# Epoch 173/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4749 - val_loss: 1.5007
# Epoch 174/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4258 - val_loss: 1.4866
# Epoch 175/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4425 - val_loss: 1.4285
# Epoch 176/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5086 - val_loss: 1.8258
# Epoch 177/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7199 - val_loss: 1.5001
# Epoch 178/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5016 - val_loss: 1.4890
# Epoch 179/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4828 - val_loss: 1.4544
# Epoch 180/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5122 - val_loss: 1.4066
# Epoch 181/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5389 - val_loss: 1.3801
# Epoch 182/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4615 - val_loss: 1.4241
# Epoch 183/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4109 - val_loss: 1.4224
# Epoch 184/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5848 - val_loss: 1.5848
# Epoch 185/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8489 - val_loss: 2.0067
# Epoch 186/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6949 - val_loss: 1.5555
# Epoch 187/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6348 - val_loss: 1.4473
# Epoch 188/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4817 - val_loss: 1.4446
# Epoch 189/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4553 - val_loss: 1.5009
# Epoch 190/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5222 - val_loss: 1.7111
# Epoch 191/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4693 - val_loss: 1.5097
# Epoch 192/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5029 - val_loss: 1.4333
# Epoch 193/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3402 - val_loss: 1.4792
# Epoch 194/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5665 - val_loss: 1.3701
# Epoch 195/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5157 - val_loss: 1.3528
# Epoch 196/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5189 - val_loss: 1.5717
# Epoch 197/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4106 - val_loss: 1.6121
# Epoch 198/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6689 - val_loss: 1.6205
# Epoch 199/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4020 - val_loss: 1.6604
# Epoch 200/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4673 - val_loss: 1.4151
# Epoch 201/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4238 - val_loss: 1.4225
# Epoch 202/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3544 - val_loss: 1.4062
# Epoch 203/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3619 - val_loss: 1.5031
# Epoch 204/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5536 - val_loss: 1.4245
# Epoch 205/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5200 - val_loss: 1.6026
# Epoch 206/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7082 - val_loss: 1.7771
# Epoch 207/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5018 - val_loss: 1.7908
# Epoch 208/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4601 - val_loss: 1.3751
# Epoch 209/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5343 - val_loss: 1.4131
# Epoch 210/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4844 - val_loss: 1.4174
# Epoch 211/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5526 - val_loss: 1.5802
# Epoch 212/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4083 - val_loss: 1.4889
# Epoch 213/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3798 - val_loss: 1.4888
# Epoch 214/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4129 - val_loss: 1.4722
# Epoch 215/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3939 - val_loss: 1.5200
# Epoch 216/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5112 - val_loss: 1.4938
# Epoch 217/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5195 - val_loss: 1.6631
# Epoch 218/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9236 - val_loss: 1.3996
# Epoch 219/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7221 - val_loss: 1.5045
# Epoch 220/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5237 - val_loss: 1.4967
# Epoch 221/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6365 - val_loss: 1.3673
# Epoch 222/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3280 - val_loss: 1.5366
# Epoch 223/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5309 - val_loss: 1.3602
# Epoch 224/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3997 - val_loss: 1.3886
# Epoch 225/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5082 - val_loss: 1.5243
# Epoch 226/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3830 - val_loss: 1.5292
# Epoch 227/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3572 - val_loss: 1.3435
# Epoch 228/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3542 - val_loss: 1.4564
# Epoch 229/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4755 - val_loss: 1.8344
# Epoch 230/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5283 - val_loss: 1.4236
# Epoch 231/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3391 - val_loss: 1.5965
# Epoch 232/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3989 - val_loss: 1.4701
# Epoch 233/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3886 - val_loss: 1.5482
# Epoch 234/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4766 - val_loss: 1.5739
# Epoch 235/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4252 - val_loss: 1.4149
# Epoch 236/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2925 - val_loss: 1.4366
# Epoch 237/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3681 - val_loss: 1.4262
# Epoch 238/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4727 - val_loss: 1.5195
# Epoch 239/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4682 - val_loss: 1.3874
# Epoch 240/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3534 - val_loss: 1.4599
# Epoch 241/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4475 - val_loss: 1.4866
# Epoch 242/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3383 - val_loss: 1.3557
# Epoch 243/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3063 - val_loss: 1.3583
# Epoch 244/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4393 - val_loss: 1.3952
# Epoch 245/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3074 - val_loss: 1.8709
# Epoch 246/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5018 - val_loss: 1.4181
# Epoch 247/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3935 - val_loss: 1.5003
# Epoch 248/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3484 - val_loss: 1.3778
# Epoch 249/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4533 - val_loss: 1.3553
# Epoch 250/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4312 - val_loss: 1.4137
# Epoch 251/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5003 - val_loss: 1.4559
# Epoch 252/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4047 - val_loss: 1.3754
# Epoch 253/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2964 - val_loss: 1.3725
# Epoch 254/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5262 - val_loss: 1.3997
# Epoch 255/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3635 - val_loss: 1.3624
# Epoch 256/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3715 - val_loss: 1.4185
# Epoch 257/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5053 - val_loss: 1.6208
# Epoch 258/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3950 - val_loss: 1.3662
# Epoch 259/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1788 - val_loss: 1.4494
# Epoch 260/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3905 - val_loss: 1.5405
# Epoch 261/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4132 - val_loss: 1.4550
# Epoch 262/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4062 - val_loss: 1.3852
# Epoch 263/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3243 - val_loss: 1.3280
# Epoch 264/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3393 - val_loss: 1.4184
# Epoch 265/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4356 - val_loss: 1.3669
# Epoch 266/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3699 - val_loss: 1.3930
# Epoch 267/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4057 - val_loss: 1.4020
# Epoch 268/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3638 - val_loss: 1.3917
# Epoch 269/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3128 - val_loss: 1.4745
# Epoch 270/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3270 - val_loss: 1.4016
# Epoch 271/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4805 - val_loss: 1.4997
# Epoch 272/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5091 - val_loss: 1.3631
# Epoch 273/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3297 - val_loss: 1.5898
# Epoch 274/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4990 - val_loss: 1.4263
# Epoch 275/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3165 - val_loss: 1.4828
# Epoch 276/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4942 - val_loss: 1.4204
# Epoch 277/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3172 - val_loss: 1.8341
# Epoch 278/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4645 - val_loss: 1.4627
# Epoch 279/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3115 - val_loss: 1.4138
# Epoch 280/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2819 - val_loss: 1.3519
# Epoch 281/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1927 - val_loss: 1.5285
# Epoch 282/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2805 - val_loss: 1.4731
# Epoch 283/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4440 - val_loss: 1.4139
# Epoch 284/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2365 - val_loss: 1.3598
# Epoch 285/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2296 - val_loss: 1.4203
# Epoch 286/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5228 - val_loss: 1.4661
# Epoch 287/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3952 - val_loss: 1.3800
# Epoch 288/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2801 - val_loss: 1.5539
# Epoch 289/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3920 - val_loss: 1.4192
# Epoch 290/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2696 - val_loss: 1.3971
# Epoch 291/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3082 - val_loss: 1.3630
# Epoch 292/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2212 - val_loss: 1.4612
# Epoch 293/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3263 - val_loss: 1.4993
# Epoch 294/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3457 - val_loss: 1.4015
# Epoch 295/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2963 - val_loss: 1.5480
# Epoch 296/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3934 - val_loss: 1.4639
# Epoch 297/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3460 - val_loss: 1.3471
# Epoch 298/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3153 - val_loss: 1.3724
# Epoch 299/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2507 - val_loss: 1.4910
# Epoch 300/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3266 - val_loss: 1.5103
# Epoch 301/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4403 - val_loss: 1.9440
# Epoch 302/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8739 - val_loss: 1.5716
# Epoch 303/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4904 - val_loss: 1.4105
# Epoch 304/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2300 - val_loss: 1.4748
# Epoch 305/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3453 - val_loss: 1.4552
# Epoch 306/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3493 - val_loss: 1.3565
# Epoch 307/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2640 - val_loss: 1.3755
# Epoch 308/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3072 - val_loss: 1.3396
# Epoch 309/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3403 - val_loss: 1.3841
# Epoch 310/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2295 - val_loss: 1.6053
# Epoch 311/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3170 - val_loss: 1.4385
# Epoch 312/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3306 - val_loss: 1.3346
# Epoch 313/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2204 - val_loss: 1.4004
# Epoch 314/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2239 - val_loss: 1.4931
# Epoch 315/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2984 - val_loss: 1.3556
# Epoch 316/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3292 - val_loss: 1.3602
# Epoch 317/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2592 - val_loss: 1.4285
# Epoch 318/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2637 - val_loss: 1.6506
# Epoch 319/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4905 - val_loss: 1.3402
# Epoch 320/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3007 - val_loss: 1.3449
# Epoch 321/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2543 - val_loss: 1.3512
# Epoch 322/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2760 - val_loss: 1.3903
# Epoch 323/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3634 - val_loss: 1.4295
# Epoch 324/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1852 - val_loss: 1.4751
# Epoch 325/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3348 - val_loss: 1.4343
# Epoch 326/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3064 - val_loss: 1.4813
# Epoch 327/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2962 - val_loss: 1.5074
# Epoch 328/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3437 - val_loss: 1.4492
# Epoch 329/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3013 - val_loss: 1.4545
# Epoch 330/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2841 - val_loss: 1.5036
# Epoch 331/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3707 - val_loss: 1.5099
# Epoch 332/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2967 - val_loss: 1.4112
# Epoch 333/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2563 - val_loss: 1.3670
# Epoch 334/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2611 - val_loss: 1.4050
# Epoch 335/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3172 - val_loss: 1.5249
# Epoch 336/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3899 - val_loss: 1.4680
# Epoch 337/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3094 - val_loss: 1.4110
# Epoch 338/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3740 - val_loss: 1.5839
# Epoch 339/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4335 - val_loss: 1.3747
# Epoch 340/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2904 - val_loss: 1.3863
# Epoch 341/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2115 - val_loss: 1.3606
# Epoch 342/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1923 - val_loss: 1.3797
# Epoch 343/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2740 - val_loss: 1.3850
# Epoch 344/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3891 - val_loss: 1.3891
# Epoch 345/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2894 - val_loss: 1.6050
# Epoch 346/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4099 - val_loss: 1.5334
# Epoch 347/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5205 - val_loss: 1.4096
# Epoch 348/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2246 - val_loss: 1.3706
# Epoch 349/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3000 - val_loss: 1.4433
# Epoch 350/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2859 - val_loss: 1.5050
# Epoch 351/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3191 - val_loss: 1.3351
# Epoch 352/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2170 - val_loss: 1.3533
# Epoch 353/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3151 - val_loss: 1.3542
# Epoch 354/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2737 - val_loss: 1.4437
# Epoch 355/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1182 - val_loss: 1.5375
# Epoch 356/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5207 - val_loss: 1.4434
# Epoch 357/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3273 - val_loss: 1.4309
# Epoch 358/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3190 - val_loss: 1.4475
# Epoch 359/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2367 - val_loss: 1.3883
# Epoch 360/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2845 - val_loss: 1.4402
# Epoch 361/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2330 - val_loss: 1.4100
# Epoch 362/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2455 - val_loss: 1.4362
# Epoch 363/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3201 - val_loss: 1.3197
# Epoch 364/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3069 - val_loss: 1.3634
# Epoch 365/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2452 - val_loss: 1.4210
# Epoch 366/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2339 - val_loss: 1.4691
# Epoch 367/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2290 - val_loss: 1.5043
# Epoch 368/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1623 - val_loss: 1.6951
# Epoch 369/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2853 - val_loss: 1.3902
# Epoch 370/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2565 - val_loss: 1.3755
# Epoch 371/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3045 - val_loss: 1.3916
# Epoch 372/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2721 - val_loss: 1.5942
# Epoch 373/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2052 - val_loss: 1.4251
# Epoch 374/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2530 - val_loss: 1.6296
# Epoch 375/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1947 - val_loss: 1.5218
# Epoch 376/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3672 - val_loss: 1.3678
# Epoch 377/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2698 - val_loss: 1.5279
# Epoch 378/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3014 - val_loss: 1.3914
# Epoch 379/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2135 - val_loss: 1.3298
# Epoch 380/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2390 - val_loss: 1.5240
# Epoch 381/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2329 - val_loss: 1.5495
# Epoch 382/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2613 - val_loss: 1.4868
# Epoch 383/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1681 - val_loss: 1.7534
# Epoch 384/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4649 - val_loss: 1.4365
# Epoch 385/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3030 - val_loss: 1.4281
# Epoch 386/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3606 - val_loss: 1.4554
# Epoch 387/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3530 - val_loss: 1.4200
# Epoch 388/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2699 - val_loss: 1.5012
# Epoch 389/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2114 - val_loss: 1.4077
# Epoch 390/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2349 - val_loss: 1.5377
# Epoch 391/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2320 - val_loss: 1.8479
# Epoch 392/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4160 - val_loss: 1.4423
# Epoch 393/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3229 - val_loss: 1.6076
# Epoch 394/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3401 - val_loss: 1.4683
# Epoch 395/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1558 - val_loss: 1.3691
# Epoch 396/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2382 - val_loss: 1.3771
# Epoch 397/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2049 - val_loss: 1.4424
# Epoch 398/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2819 - val_loss: 1.5515
# Epoch 399/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1946 - val_loss: 1.4818
# Epoch 400/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2154 - val_loss: 1.4084
# Epoch 401/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2392 - val_loss: 1.4621
# Epoch 402/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1975 - val_loss: 1.3583
# Epoch 403/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1907 - val_loss: 1.3570
# Epoch 404/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2097 - val_loss: 1.4268
# Epoch 405/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3087 - val_loss: 1.6343
# Epoch 406/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4368 - val_loss: 1.3436
# Epoch 407/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2140 - val_loss: 1.4899
# Epoch 408/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3129 - val_loss: 1.3746
# Epoch 409/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4815 - val_loss: 1.4023
# Epoch 410/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3564 - val_loss: 1.4647
# Epoch 411/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2081 - val_loss: 1.3604
# Epoch 412/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1894 - val_loss: 1.3664
# Epoch 413/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2816 - val_loss: 1.3539
# Epoch 414/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1895 - val_loss: 1.4052
# Epoch 415/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3058 - val_loss: 1.8383
# Epoch 416/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5380 - val_loss: 1.4084
# Epoch 417/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2447 - val_loss: 1.4186
# Epoch 418/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2685 - val_loss: 1.4767
# Epoch 419/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2656 - val_loss: 1.3849
# Epoch 420/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2268 - val_loss: 1.4401
# Epoch 421/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2371 - val_loss: 1.3454
# Epoch 422/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1791 - val_loss: 1.4843
# Epoch 423/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2314 - val_loss: 1.4320
# Epoch 424/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2587 - val_loss: 1.3825
# Epoch 425/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2526 - val_loss: 1.3877
# Epoch 426/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1680 - val_loss: 1.4767
# Epoch 427/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3054 - val_loss: 1.4426
# Epoch 428/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2647 - val_loss: 1.3500
# Epoch 429/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2324 - val_loss: 1.4009
# Epoch 430/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1906 - val_loss: 1.4099
# Epoch 431/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2126 - val_loss: 1.3908
# Epoch 432/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2519 - val_loss: 1.3688
# Epoch 433/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1483 - val_loss: 1.5778
# Epoch 434/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2202 - val_loss: 1.4136
# Epoch 435/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2839 - val_loss: 1.4150
# Epoch 436/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2579 - val_loss: 1.3598
# Epoch 437/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2113 - val_loss: 1.4502
# Epoch 438/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1779 - val_loss: 1.4164
# Epoch 439/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2108 - val_loss: 1.3457
# Epoch 440/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1671 - val_loss: 1.4319
# Epoch 441/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2103 - val_loss: 1.3598
# Epoch 442/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2810 - val_loss: 1.3970
# Epoch 443/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3226 - val_loss: 1.3970
# Epoch 444/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2255 - val_loss: 1.3609
# Epoch 445/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2310 - val_loss: 1.4586
# Epoch 446/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4543 - val_loss: 1.7434
# Epoch 447/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2856 - val_loss: 1.4516
# Epoch 448/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1423 - val_loss: 1.3645
# Epoch 449/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1383 - val_loss: 1.6389
# Epoch 450/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2303 - val_loss: 1.5135
# Epoch 451/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2416 - val_loss: 1.4033
# Epoch 452/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2370 - val_loss: 1.3504
# Epoch 453/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1785 - val_loss: 1.4225
# Epoch 454/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0816 - val_loss: 1.3856
# Epoch 455/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2210 - val_loss: 1.3692
# Epoch 456/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1593 - val_loss: 1.4229
# Epoch 457/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2530 - val_loss: 1.3512
# Epoch 458/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2816 - val_loss: 1.3634
# Epoch 459/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1679 - val_loss: 1.4943
# Epoch 460/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1848 - val_loss: 1.5194
# Epoch 461/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2285 - val_loss: 1.4333
# Epoch 462/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3299 - val_loss: 1.5280
# Epoch 463/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2596 - val_loss: 1.4228
# Epoch 464/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1434 - val_loss: 1.4076
# Epoch 465/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2134 - val_loss: 1.3309
# Epoch 466/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2545 - val_loss: 1.4253
# Epoch 467/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2874 - val_loss: 1.3845
# Epoch 468/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1660 - val_loss: 1.4323
# Epoch 469/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2723 - val_loss: 1.4016
# Epoch 470/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3210 - val_loss: 1.4035
# Epoch 471/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2832 - val_loss: 1.3451
# Epoch 472/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0992 - val_loss: 1.3768
# Epoch 473/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3191 - val_loss: 1.4465
# Epoch 474/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5156 - val_loss: 1.3925
# Epoch 475/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2700 - val_loss: 1.6025
# Epoch 476/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3683 - val_loss: 1.4267
# Epoch 477/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2367 - val_loss: 1.4300
# Epoch 478/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2365 - val_loss: 1.4064
# Epoch 479/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2075 - val_loss: 1.4814
# Epoch 480/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1405 - val_loss: 1.4502
# Epoch 481/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2148 - val_loss: 1.4201
# Epoch 482/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2819 - val_loss: 1.4256
# Epoch 483/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1976 - val_loss: 1.3358
# Epoch 484/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0896 - val_loss: 1.3606
# Epoch 485/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1637 - val_loss: 1.3461
# Epoch 486/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2067 - val_loss: 1.4115
# Epoch 487/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2403 - val_loss: 1.4205
# Epoch 488/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2148 - val_loss: 1.5381
# Epoch 489/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3136 - val_loss: 1.3743
# Epoch 490/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2885 - val_loss: 1.4788
# Epoch 491/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2072 - val_loss: 1.3496
# Epoch 492/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1476 - val_loss: 1.4185
# Epoch 493/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1196 - val_loss: 1.3781
# Epoch 494/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1872 - val_loss: 1.3962
# Epoch 495/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1452 - val_loss: 1.3947
# Epoch 496/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1828 - val_loss: 1.5609
# Epoch 497/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2337 - val_loss: 1.3600
# Epoch 498/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2687 - val_loss: 1.4470
# Epoch 499/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2852 - val_loss: 1.3683
# Epoch 500/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1566 - val_loss: 1.4499
# Shape of X_test: (320, 85)

# %%
# Predict the test set results
y_pred_nn = model.predict(X_test)

# No need to reshape y_pred_nn


mae_nn = mean_absolute_error(y_test, y_pred_nn)
mse_nn = mean_squared_error(y_test, y_pred_nn)
rmse_nn = np.sqrt(mse_nn)
medae_nn = median_absolute_error(y_test, y_pred_nn)
 
evs_nn = explained_variance_score(y_test, y_pred_nn)

print("Neural Network Metrics:")
print(f"MAE: {mae_nn}, MSE: {mse_nn}, RMSE: {rmse_nn}, MedAE: {medae_nn}, EVS: {evs_nn}\n")
def nse(y_true, y_pred):
    y_true = y_true.values.ravel().astype(float)
    y_pred = y_pred.ravel().astype(float)
    return 1 - np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2)

# Calculate NSE for the model
nse_nn = nse(y_test, y_pred_nn)

print(f"Neural Network NSE: {nse_nn}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Neural Network Metrics:
# MAE: 1.8682358264923096, MSE: 9.168092727661133, RMSE: 3.0278858511610265, MedAE: 1.1616763651371, EVS: 0.9840598619713778
#
# Neural Network NSE: 0.9836271322069225

# %% [markdown]
# Adding graphs.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the width of the bars
barWidth = 0.15

# Assuming you have these metrics for each model
metrics = {
    'Gradient Boosting': {'MAE': mae_gb, 'MSE': mse_gb, 'RMSE': rmse_gb, 'MedAE': medae_gb, 'EVS': evs_gb},
    'RandomForest': {'MAE': mae_rf, 'MSE': mse_rf, 'RMSE': rmse_rf, 'MedAE': medae_rf, 'EVS': evs_rf},
    'Neural Network': {'MAE': mae_nn, 'MSE': mse_nn, 'RMSE': rmse_nn, 'MedAE': medae_nn, 'EVS': evs_nn}
}

# Restructure the data
metrics_by_model = {
    'MAE': {model: metrics[model]['MAE'] for model in metrics},
    'MSE': {model: metrics[model]['MSE'] for model in metrics},
    'RMSE': {model: metrics[model]['RMSE'] for model in metrics},
    'MedAE': {model: metrics[model]['MedAE'] for model in metrics},
    'EVS': {model: metrics[model]['EVS'] for model in metrics},
}

# Set position of bar on X axis
r1 = np.arange(len(metrics_by_model))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.figure(figsize=(12, 8))

# Make the plot
colors = ['b', 'r', 'g', 'y', 'm', 'c']  # Add more colors if needed
for i, model in enumerate(metrics):
    plt.bar([r + i*barWidth for r in r1], list(metrics[model].values()), color=colors[i % len(colors)], width=barWidth, edgecolor='grey', label=model)

# Adding xticks
plt.xlabel('Metrics', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(metrics_by_model))], [metric for metric in metrics_by_model])
plt.legend()
plt.grid()
plt.show()

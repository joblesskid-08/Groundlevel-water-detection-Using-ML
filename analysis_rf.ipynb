# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.metrics import r2_score
from sklearn.multioutput import MultiOutputRegressor

from sklearn.metrics import mean_squared_log_error, median_absolute_error, explained_variance_score, max_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Read the csv file
df2 = pd.read_csv(r'C:\Users\visha\Downloads\sih-main\merged.csv')
df = pd.read_csv('modified_file2.csv')

# %% [markdown]
# Performing Exploratory Data Analysis(EDA)

# %%
months = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']

corelation_pre = [df['Post-monsoon_2022 (meters below ground level)'].corr(df[month]) for month in months]
corelation_post = [df['Pre-monsoon_2022 (meters below ground level)'].corr(df[month]) for month in months]

x = range(len(months))

plt.figure(figsize=(12, 6))

plt.bar(x, corelation_pre, width=0.4, label='Pre-monsoon', color='b', align='center')
plt.bar(x, corelation_post, width=0.4, label='Post-monsoon', color='r', align='edge')

plt.xlabel('Months')
plt.ylabel('Correlation')
plt.title('Correlation between each month of rainfall and the pre-monsoon post-monsoon level')
plt.xticks(x, months, rotation='vertical')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Now defining the features variables (using the pre & post moonsoon data from 2015 to 2021 )

# %%
features1 = df[['Pre-monsoon_2015 (meters below ground level)', 'Post-monsoon_2015 (meters below ground level)', 'Pre-monsoon_2016 (meters below ground level)', 'Post-monsoon_2016 (meters below ground level)', 'Pre-monsoon_2017 (meters below ground level)', 'Post-monsoon_2017 (meters below ground level)', 'Pre-monsoon_2018 (meters below ground level)', 'Post-monsoon_2018 (meters below ground level)', 'Pre-monsoon_2019 (meters below ground level)', 'Post-monsoon_2019 (meters below ground level)', 'Pre-monsoon_2020 (meters below ground level)', 'Post-monsoon_2020 (meters below ground level)', 'Pre-monsoon_2021 (meters below ground level)', 'Post-monsoon_2021 (meters below ground level)', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec' ]]
aquifer_encoded = pd.get_dummies(df['Aquifer'])

# Concatenate the one-hot encoded dataframe with the original features dataframe
features = pd.concat([features1, aquifer_encoded], axis=1)

# %% [markdown]
# Defining the target variables. (predicting the pre & post moonsoon data from 2022)

# %%
target = df[['Pre-monsoon_2022 (meters below ground level)', 'Post-monsoon_2022 (meters below ground level)']]

# %% [markdown]
# Splitting the data into training and testing datasets.

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
#Currently using 50/50 split
model = MultiOutputRegressor(GradientBoostingRegressor(random_state=0))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(random_state=0))

# %% [markdown]
# Evaluation of the model

# %%
y_pred = model.predict(X_test)
score = r2_score(y_test, y_pred)

print(f'The model score is {score}')
# Out:
# The model score is 0.9783020357113112

# %% [markdown]
# now using random-forest.

# %%
model_rf = MultiOutputRegressor(RandomForestRegressor(random_state=0))

# Fit the model
model_rf.fit(X_train, y_train)

# Predict the test set results
y_pred_rf = model_rf.predict(X_test)

# Calculate the R2 score
score_rf = r2_score(y_test, y_pred_rf)

# %% [markdown]
# Evaluating random forest model.

# %%
print(f'The Random Forest model score is {score_rf}')
# Out:
# The Random Forest model score is 0.9794926404875631

# %% [markdown]
# Graphing the models comparitively

# %%
models = ['Gradient Boosting', 'Random Forest']

# Corresponding scores
scores = [score, score_rf]

plt.bar(models, scores, color=['blue', 'green'])
plt.xlabel('Models')
plt.ylabel('R2 Score')
plt.title('Comparison of Model Performance (R-squared score)')
plt.show()

# %% [markdown]
# Now comparing on other matrices.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Calculate metrics for Gradient Boosting
mae_gb = mean_absolute_error(y_test, y_pred)
mse_gb = mean_squared_error(y_test, y_pred)
rmse_gb = np.sqrt(mse_gb)

# Calculate metrics for Random Forest
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)

# Define the models and their corresponding metrics
models = ['Gradient Boosting', 'Random Forest']
mae_scores = [mae_gb, mae_rf]
mse_scores = [mse_gb, mse_rf]
rmse_scores = [rmse_gb, rmse_rf]


# Calculate additional metrics for Gradient Boosting
medae_gb = median_absolute_error(y_test, y_pred)
evs_gb = explained_variance_score(y_test, y_pred)

# Calculate additional metrics for Random Forest
medae_rf = median_absolute_error(y_test, y_pred_rf)
evs_rf = explained_variance_score(y_test, y_pred_rf)

# Print all metrics for both models
print("Gradient Boosting Metrics:")
print(f"MAE: {mae_gb}, MSE: {mse_gb}, RMSE: {rmse_gb}, MedAE: {medae_gb}, EVS: {evs_gb}\n")

print("Random Forest Metrics:")
print(f"MAE: {mae_rf}, MSE: {mse_rf}, RMSE: {rmse_rf}, MedAE: {medae_rf}, EVS: {evs_rf}\n")
# Out:
# Gradient Boosting Metrics:
# MAE: 1.9411232584322748, MSE: 12.11825652164185, RMSE: 3.481128627563459, MedAE: 1.1520591939886218, EVS: 0.9783441469587069
#
# Random Forest Metrics:
# MAE: 1.868200000000001, MSE: 11.376646612750005, RMSE: 3.3729284920896268, MedAE: 1.0556500000000049, EVS: 0.9795648688446411

# %% [markdown]
# Now using a neural Network.
# We are using neural network from tensorflow.

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential

# %% [markdown]
# For simplicity, let's create a model with one hidden layer. The input and output layer sizes should match the number of features and the number of output variables, respectively.

# %%
from tensorflow.keras.losses import Huber
model = Sequential()
model.add(Input(shape=(len(X_train.columns),)))  # Input layer
model.add(Dense(32, activation='relu'))# Hidden layer
model.add(Dense(32, activation='relu'))# Hidden layer
model.add(Dense(2))  # Output layer
model.compile(loss='huber', optimizer='adam')
# Train the model on the training data
history = model.fit(X_train, y_train, epochs=500, validation_data=(X_test, y_test))
print(f"Shape of X_test: {X_test.shape}")
# Out:
# Epoch 1/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 39.2638 - val_loss: 8.9009
# Epoch 2/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5835 - val_loss: 3.5372
# Epoch 3/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0739 - val_loss: 2.9610
# Epoch 4/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1297 - val_loss: 2.7955
# Epoch 5/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9162 - val_loss: 2.9613
# Epoch 6/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6926 - val_loss: 3.1430
# Epoch 7/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6426 - val_loss: 3.0225
# Epoch 8/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7199 - val_loss: 2.6393
# Epoch 9/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4654 - val_loss: 2.5823
# Epoch 10/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4324 - val_loss: 3.0838
# Epoch 11/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5252 - val_loss: 2.4454
# Epoch 12/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5080 - val_loss: 2.6521
# Epoch 13/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4246 - val_loss: 2.5345
# Epoch 14/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4073 - val_loss: 2.3785
# Epoch 15/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5137 - val_loss: 2.4568
# Epoch 16/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3515 - val_loss: 2.3736
# Epoch 17/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2981 - val_loss: 2.2651
# Epoch 18/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0670 - val_loss: 2.5465
# Epoch 19/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1796 - val_loss: 2.2555
# Epoch 20/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0677 - val_loss: 2.5425
# Epoch 21/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2322 - val_loss: 2.0895
# Epoch 22/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9501 - val_loss: 2.1693
# Epoch 23/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2917 - val_loss: 2.2814
# Epoch 24/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1858 - val_loss: 2.7655
# Epoch 25/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5181 - val_loss: 2.2631
# Epoch 26/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1794 - val_loss: 2.1217
# Epoch 27/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9696 - val_loss: 2.2679
# Epoch 28/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0745 - val_loss: 1.9605
# Epoch 29/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9023 - val_loss: 1.9433
# Epoch 30/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9721 - val_loss: 1.8966
# Epoch 31/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8937 - val_loss: 2.1516
# Epoch 32/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8910 - val_loss: 1.7741
# Epoch 33/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0421 - val_loss: 1.8808
# Epoch 34/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8979 - val_loss: 2.2967
# Epoch 35/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1484 - val_loss: 1.7299
# Epoch 36/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8032 - val_loss: 1.8524
# Epoch 37/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0546 - val_loss: 2.0582
# Epoch 38/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9518 - val_loss: 1.8915
# Epoch 39/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9719 - val_loss: 1.8535
# Epoch 40/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8603 - val_loss: 1.8554
# Epoch 41/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7618 - val_loss: 1.7744
# Epoch 42/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7958 - val_loss: 1.6348
# Epoch 43/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7021 - val_loss: 1.6992
# Epoch 44/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8902 - val_loss: 1.5914
# Epoch 45/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7126 - val_loss: 1.6562
# Epoch 46/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6221 - val_loss: 1.5873
# Epoch 47/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5587 - val_loss: 1.7077
# Epoch 48/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8626 - val_loss: 1.5679
# Epoch 49/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7152 - val_loss: 1.6932
# Epoch 50/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6369 - val_loss: 1.6732
# Epoch 51/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8317 - val_loss: 1.6379
# Epoch 52/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8164 - val_loss: 1.5776
# Epoch 53/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8677 - val_loss: 1.6118
# Epoch 54/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7354 - val_loss: 1.6348
# Epoch 55/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7223 - val_loss: 1.5626
# Epoch 56/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6294 - val_loss: 1.5580
# Epoch 57/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6833 - val_loss: 1.6100
# Epoch 58/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7413 - val_loss: 1.6486
# Epoch 59/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9731 - val_loss: 1.5338
# Epoch 60/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6162 - val_loss: 1.7736
# Epoch 61/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8806 - val_loss: 1.6535
# Epoch 62/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8989 - val_loss: 1.9320
# Epoch 63/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8492 - val_loss: 1.5780
# Epoch 64/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7654 - val_loss: 1.5732
# Epoch 65/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5457 - val_loss: 1.5780
# Epoch 66/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6946 - val_loss: 1.4884
# Epoch 67/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6853 - val_loss: 1.6041
# Epoch 68/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5761 - val_loss: 2.0236
# Epoch 69/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0137 - val_loss: 1.5656
# Epoch 70/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5478 - val_loss: 1.5441
# Epoch 71/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7559 - val_loss: 1.4673
# Epoch 72/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7036 - val_loss: 1.5322
# Epoch 73/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7504 - val_loss: 1.5199
# Epoch 74/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6074 - val_loss: 1.6410
# Epoch 75/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5155 - val_loss: 1.5063
# Epoch 76/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5346 - val_loss: 1.5194
# Epoch 77/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5031 - val_loss: 1.5367
# Epoch 78/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7094 - val_loss: 1.7186
# Epoch 79/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7257 - val_loss: 1.5509
# Epoch 80/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9173 - val_loss: 1.4755
# Epoch 81/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5256 - val_loss: 1.4663
# Epoch 82/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6254 - val_loss: 1.6685
# Epoch 83/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7563 - val_loss: 1.5352
# Epoch 84/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5330 - val_loss: 1.6172
# Epoch 85/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7712 - val_loss: 2.1353
# Epoch 86/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5250 - val_loss: 1.4637
# Epoch 87/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7088 - val_loss: 1.4849
# Epoch 88/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7353 - val_loss: 1.4451
# Epoch 89/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4315 - val_loss: 1.6458
# Epoch 90/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9846 - val_loss: 1.7030
# Epoch 91/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7616 - val_loss: 1.4485
# Epoch 92/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6173 - val_loss: 1.5082
# Epoch 93/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6940 - val_loss: 1.4853
# Epoch 94/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4290 - val_loss: 1.5148
# Epoch 95/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7333 - val_loss: 1.4461
# Epoch 96/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6178 - val_loss: 1.4352
# Epoch 97/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7181 - val_loss: 1.6300
# Epoch 98/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6608 - val_loss: 1.4642
# Epoch 99/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5908 - val_loss: 1.7280
# Epoch 100/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7258 - val_loss: 1.4244
# Epoch 101/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5597 - val_loss: 1.5043
# Epoch 102/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8769 - val_loss: 1.7505
# Epoch 103/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6418 - val_loss: 1.6240
# Epoch 104/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6201 - val_loss: 1.4170
# Epoch 105/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5747 - val_loss: 1.4093
# Epoch 106/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5824 - val_loss: 1.7159
# Epoch 107/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6242 - val_loss: 1.4533
# Epoch 108/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5793 - val_loss: 1.5398
# Epoch 109/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6709 - val_loss: 1.5896
# Epoch 110/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7119 - val_loss: 1.4795
# Epoch 111/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5946 - val_loss: 1.5287
# Epoch 112/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5314 - val_loss: 1.5038
# Epoch 113/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4479 - val_loss: 1.6597
# Epoch 114/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5860 - val_loss: 1.5181
# Epoch 115/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5109 - val_loss: 1.5645
# Epoch 116/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5282 - val_loss: 1.5280
# Epoch 117/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5483 - val_loss: 1.7269
# Epoch 118/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9351 - val_loss: 1.4134
# Epoch 119/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5620 - val_loss: 1.4635
# Epoch 120/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5665 - val_loss: 1.5510
# Epoch 121/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6918 - val_loss: 1.4643
# Epoch 122/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5757 - val_loss: 1.4224
# Epoch 123/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5140 - val_loss: 1.5712
# Epoch 124/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6297 - val_loss: 1.4992
# Epoch 125/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6316 - val_loss: 1.4290
# Epoch 126/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5533 - val_loss: 1.5914
# Epoch 127/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5047 - val_loss: 1.4094
# Epoch 128/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3533 - val_loss: 1.4967
# Epoch 129/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4748 - val_loss: 1.4512
# Epoch 130/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4505 - val_loss: 1.5026
# Epoch 131/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4727 - val_loss: 1.5690
# Epoch 132/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5129 - val_loss: 1.5229
# Epoch 133/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5713 - val_loss: 1.4203
# Epoch 134/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4642 - val_loss: 1.7700
# Epoch 135/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8411 - val_loss: 1.4832
# Epoch 136/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8714 - val_loss: 1.5205
# Epoch 137/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6702 - val_loss: 1.5555
# Epoch 138/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5893 - val_loss: 1.4289
# Epoch 139/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5360 - val_loss: 1.3935
# Epoch 140/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3885 - val_loss: 1.4043
# Epoch 141/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4423 - val_loss: 1.5485
# Epoch 142/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4890 - val_loss: 1.6931
# Epoch 143/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5414 - val_loss: 1.3983
# Epoch 144/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4965 - val_loss: 1.4888
# Epoch 145/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5623 - val_loss: 1.4107
# Epoch 146/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7219 - val_loss: 1.5770
# Epoch 147/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3932 - val_loss: 1.4966
# Epoch 148/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5395 - val_loss: 1.4190
# Epoch 149/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7676 - val_loss: 1.8844
# Epoch 150/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8049 - val_loss: 1.6136
# Epoch 151/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5223 - val_loss: 1.4564
# Epoch 152/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6122 - val_loss: 1.4127
# Epoch 153/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4366 - val_loss: 1.5371
# Epoch 154/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7681 - val_loss: 1.4882
# Epoch 155/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5365 - val_loss: 1.9122
# Epoch 156/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5854 - val_loss: 1.3938
# Epoch 157/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6595 - val_loss: 1.6579
# Epoch 158/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5305 - val_loss: 1.4164
# Epoch 159/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5211 - val_loss: 1.4325
# Epoch 160/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4734 - val_loss: 1.7778
# Epoch 161/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5771 - val_loss: 1.4161
# Epoch 162/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6615 - val_loss: 1.3955
# Epoch 163/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5455 - val_loss: 1.4697
# Epoch 164/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5537 - val_loss: 1.5589
# Epoch 165/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4721 - val_loss: 1.3923
# Epoch 166/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6692 - val_loss: 1.5990
# Epoch 167/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5330 - val_loss: 1.4448
# Epoch 168/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6156 - val_loss: 1.4067
# Epoch 169/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6674 - val_loss: 1.4271
# Epoch 170/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4401 - val_loss: 1.4575
# Epoch 171/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4802 - val_loss: 1.4528
# Epoch 172/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4627 - val_loss: 1.4408
# Epoch 173/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4012 - val_loss: 1.4989
# Epoch 174/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6090 - val_loss: 1.4781
# Epoch 175/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4884 - val_loss: 1.6308
# Epoch 176/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6346 - val_loss: 1.4115
# Epoch 177/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4868 - val_loss: 1.4116
# Epoch 178/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5257 - val_loss: 1.4706
# Epoch 179/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6406 - val_loss: 1.4047
# Epoch 180/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4782 - val_loss: 1.4957
# Epoch 181/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5368 - val_loss: 1.4026
# Epoch 182/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7244 - val_loss: 1.4942
# Epoch 183/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5350 - val_loss: 1.3886
# Epoch 184/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4198 - val_loss: 1.4164
# Epoch 185/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4232 - val_loss: 1.5926
# Epoch 186/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5480 - val_loss: 1.4499
# Epoch 187/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5559 - val_loss: 1.4152
# Epoch 188/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4027 - val_loss: 1.3950
# Epoch 189/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4854 - val_loss: 1.4351
# Epoch 190/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5300 - val_loss: 1.4934
# Epoch 191/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5821 - val_loss: 1.4661
# Epoch 192/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5263 - val_loss: 1.4362
# Epoch 193/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4023 - val_loss: 1.4517
# Epoch 194/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5643 - val_loss: 1.4107
# Epoch 195/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4009 - val_loss: 1.5592
# Epoch 196/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5173 - val_loss: 1.5033
# Epoch 197/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4560 - val_loss: 1.4555
# Epoch 198/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3985 - val_loss: 1.4539
# Epoch 199/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4961 - val_loss: 1.5059
# Epoch 200/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4588 - val_loss: 1.4138
# Epoch 201/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4814 - val_loss: 1.3663
# Epoch 202/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3947 - val_loss: 1.4442
# Epoch 203/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4788 - val_loss: 1.4452
# Epoch 204/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4937 - val_loss: 1.4143
# Epoch 205/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3746 - val_loss: 1.3647
# Epoch 206/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4944 - val_loss: 1.4253
# Epoch 207/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4342 - val_loss: 1.3968
# Epoch 208/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4773 - val_loss: 1.4084
# Epoch 209/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3999 - val_loss: 1.3783
# Epoch 210/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4071 - val_loss: 1.4260
# Epoch 211/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5082 - val_loss: 1.4022
# Epoch 212/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3925 - val_loss: 1.4385
# Epoch 213/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3809 - val_loss: 1.3830
# Epoch 214/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3945 - val_loss: 1.5103
# Epoch 215/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5855 - val_loss: 1.4276
# Epoch 216/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4194 - val_loss: 1.8695
# Epoch 217/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7894 - val_loss: 1.5203
# Epoch 218/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5177 - val_loss: 1.4889
# Epoch 219/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5819 - val_loss: 1.3950
# Epoch 220/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3219 - val_loss: 1.4329
# Epoch 221/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3964 - val_loss: 1.4746
# Epoch 222/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3960 - val_loss: 1.8904
# Epoch 223/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7478 - val_loss: 1.5171
# Epoch 224/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4541 - val_loss: 1.3983
# Epoch 225/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3601 - val_loss: 1.5386
# Epoch 226/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6664 - val_loss: 1.6910
# Epoch 227/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6473 - val_loss: 1.4399
# Epoch 228/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5878 - val_loss: 1.5945
# Epoch 229/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4650 - val_loss: 1.5063
# Epoch 230/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3510 - val_loss: 1.4788
# Epoch 231/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5132 - val_loss: 1.4399
# Epoch 232/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5794 - val_loss: 1.4967
# Epoch 233/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4532 - val_loss: 1.5044
# Epoch 234/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3951 - val_loss: 1.4537
# Epoch 235/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4587 - val_loss: 1.5353
# Epoch 236/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4064 - val_loss: 1.4555
# Epoch 237/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5394 - val_loss: 1.3754
# Epoch 238/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4443 - val_loss: 1.4363
# Epoch 239/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3619 - val_loss: 1.5580
# Epoch 240/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3313 - val_loss: 1.4169
# Epoch 241/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4538 - val_loss: 1.3956
# Epoch 242/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3192 - val_loss: 1.6252
# Epoch 243/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7084 - val_loss: 1.4415
# Epoch 244/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3395 - val_loss: 1.4377
# Epoch 245/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5556 - val_loss: 1.3852
# Epoch 246/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6067 - val_loss: 1.3888
# Epoch 247/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5114 - val_loss: 1.4174
# Epoch 248/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5241 - val_loss: 1.4735
# Epoch 249/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4360 - val_loss: 1.5957
# Epoch 250/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5969 - val_loss: 1.4781
# Epoch 251/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5172 - val_loss: 1.3782
# Epoch 252/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3485 - val_loss: 1.5724
# Epoch 253/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5357 - val_loss: 1.4327
# Epoch 254/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4581 - val_loss: 1.4572
# Epoch 255/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5524 - val_loss: 1.4175
# Epoch 256/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4086 - val_loss: 1.5315
# Epoch 257/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3290 - val_loss: 1.5138
# Epoch 258/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3800 - val_loss: 1.5333
# Epoch 259/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5470 - val_loss: 1.4299
# Epoch 260/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2367 - val_loss: 1.5467
# Epoch 261/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2978 - val_loss: 1.4250
# Epoch 262/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2604 - val_loss: 1.6804
# Epoch 263/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5477 - val_loss: 1.5061
# Epoch 264/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5253 - val_loss: 1.4768
# Epoch 265/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3898 - val_loss: 1.5772
# Epoch 266/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5762 - val_loss: 1.3837
# Epoch 267/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4207 - val_loss: 1.3835
# Epoch 268/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4706 - val_loss: 1.3878
# Epoch 269/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4162 - val_loss: 1.3892
# Epoch 270/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5617 - val_loss: 1.5481
# Epoch 271/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5778 - val_loss: 1.5243
# Epoch 272/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3442 - val_loss: 1.3997
# Epoch 273/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4687 - val_loss: 1.6066
# Epoch 274/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5075 - val_loss: 1.5352
# Epoch 275/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3043 - val_loss: 1.4761
# Epoch 276/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4752 - val_loss: 1.5718
# Epoch 277/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5756 - val_loss: 1.4410
# Epoch 278/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3131 - val_loss: 1.4348
# Epoch 279/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1877 - val_loss: 1.6228
# Epoch 280/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3826 - val_loss: 1.6160
# Epoch 281/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4763 - val_loss: 1.4453
# Epoch 282/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4585 - val_loss: 1.4701
# Epoch 283/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4342 - val_loss: 1.4989
# Epoch 284/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3476 - val_loss: 1.4855
# Epoch 285/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3919 - val_loss: 1.4543
# Epoch 286/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4231 - val_loss: 1.4362
# Epoch 287/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2792 - val_loss: 1.4551
# Epoch 288/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3703 - val_loss: 1.4151
# Epoch 289/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2880 - val_loss: 1.3845
# Epoch 290/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3964 - val_loss: 1.3836
# Epoch 291/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4990 - val_loss: 1.4255
# Epoch 292/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3015 - val_loss: 1.5048
# Epoch 293/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4447 - val_loss: 1.3870
# Epoch 294/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5165 - val_loss: 1.3935
# Epoch 295/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3404 - val_loss: 1.6923
# Epoch 296/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4738 - val_loss: 1.4095
# Epoch 297/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3458 - val_loss: 1.4152
# Epoch 298/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3201 - val_loss: 1.5863
# Epoch 299/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3922 - val_loss: 1.5521
# Epoch 300/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3078 - val_loss: 1.4611
# Epoch 301/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3163 - val_loss: 1.5311
# Epoch 302/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4378 - val_loss: 1.4478
# Epoch 303/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3237 - val_loss: 1.4698
# Epoch 304/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5567 - val_loss: 1.5468
# Epoch 305/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4312 - val_loss: 1.4266
# Epoch 306/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3542 - val_loss: 1.4044
# Epoch 307/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4482 - val_loss: 1.3884
# Epoch 308/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2691 - val_loss: 1.4277
# Epoch 309/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3607 - val_loss: 1.4386
# Epoch 310/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3842 - val_loss: 1.4562
# Epoch 311/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3515 - val_loss: 1.4472
# Epoch 312/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4785 - val_loss: 1.3969
# Epoch 313/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3501 - val_loss: 1.3598
# Epoch 314/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5200 - val_loss: 1.4726
# Epoch 315/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2559 - val_loss: 1.5269
# Epoch 316/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4766 - val_loss: 1.6446
# Epoch 317/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3936 - val_loss: 1.4225
# Epoch 318/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5740 - val_loss: 1.4103
# Epoch 319/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2917 - val_loss: 1.4781
# Epoch 320/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3961 - val_loss: 1.3771
# Epoch 321/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3072 - val_loss: 1.4495
# Epoch 322/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4894 - val_loss: 1.3967
# Epoch 323/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3998 - val_loss: 1.4344
# Epoch 324/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3408 - val_loss: 1.4089
# Epoch 325/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3093 - val_loss: 1.4104
# Epoch 326/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3652 - val_loss: 1.3682
# Epoch 327/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4678 - val_loss: 1.4979
# Epoch 328/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6190 - val_loss: 1.5430
# Epoch 329/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3543 - val_loss: 1.4260
# Epoch 330/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3455 - val_loss: 1.4054
# Epoch 331/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3722 - val_loss: 1.4560
# Epoch 332/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3233 - val_loss: 1.4681
# Epoch 333/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3451 - val_loss: 1.4234
# Epoch 334/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4236 - val_loss: 1.4004
# Epoch 335/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3844 - val_loss: 1.5141
# Epoch 336/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5257 - val_loss: 1.5172
# Epoch 337/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2767 - val_loss: 1.4228
# Epoch 338/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3892 - val_loss: 1.4245
# Epoch 339/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3523 - val_loss: 1.6659
# Epoch 340/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3905 - val_loss: 1.4914
# Epoch 341/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2412 - val_loss: 1.4964
# Epoch 342/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4602 - val_loss: 1.4352
# Epoch 343/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4030 - val_loss: 1.4014
# Epoch 344/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2374 - val_loss: 1.3835
# Epoch 345/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3972 - val_loss: 1.5912
# Epoch 346/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5122 - val_loss: 1.4105
# Epoch 347/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3242 - val_loss: 1.5594
# Epoch 348/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4259 - val_loss: 1.4644
# Epoch 349/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4738 - val_loss: 1.5039
# Epoch 350/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4235 - val_loss: 1.4104
# Epoch 351/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4617 - val_loss: 1.5867
# Epoch 352/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3194 - val_loss: 1.5651
# Epoch 353/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4125 - val_loss: 1.4654
# Epoch 354/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3299 - val_loss: 1.5760
# Epoch 355/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6070 - val_loss: 1.4510
# Epoch 356/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3120 - val_loss: 1.5568
# Epoch 357/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3257 - val_loss: 1.4870
# Epoch 358/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3841 - val_loss: 1.4043
# Epoch 359/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3913 - val_loss: 1.3842
# Epoch 360/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5160 - val_loss: 1.4070
# Epoch 361/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3888 - val_loss: 1.5456
# Epoch 362/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3640 - val_loss: 1.4137
# Epoch 363/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4200 - val_loss: 1.3956
# Epoch 364/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3363 - val_loss: 1.4686
# Epoch 365/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3272 - val_loss: 1.4670
# Epoch 366/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5934 - val_loss: 1.4259
# Epoch 367/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6139 - val_loss: 1.3942
# Epoch 368/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3366 - val_loss: 1.4973
# Epoch 369/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4334 - val_loss: 1.4479
# Epoch 370/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3639 - val_loss: 1.4533
# Epoch 371/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2835 - val_loss: 1.4249
# Epoch 372/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1897 - val_loss: 1.4214
# Epoch 373/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3606 - val_loss: 1.5166
# Epoch 374/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3583 - val_loss: 1.5543
# Epoch 375/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3270 - val_loss: 1.4440
# Epoch 376/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4502 - val_loss: 1.3848
# Epoch 377/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2915 - val_loss: 1.4180
# Epoch 378/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2403 - val_loss: 1.3777
# Epoch 379/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5674 - val_loss: 1.4526
# Epoch 380/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2777 - val_loss: 1.5243
# Epoch 381/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4121 - val_loss: 1.4835
# Epoch 382/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3237 - val_loss: 1.4189
# Epoch 383/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2961 - val_loss: 1.4713
# Epoch 384/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3259 - val_loss: 1.6306
# Epoch 385/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4405 - val_loss: 1.4879
# Epoch 386/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3146 - val_loss: 1.4384
# Epoch 387/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2116 - val_loss: 1.4394
# Epoch 388/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4074 - val_loss: 1.5116
# Epoch 389/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2254 - val_loss: 1.4757
# Epoch 390/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3806 - val_loss: 1.4859
# Epoch 391/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4873 - val_loss: 1.3893
# Epoch 392/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1827 - val_loss: 1.4032
# Epoch 393/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3157 - val_loss: 1.4651
# Epoch 394/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2579 - val_loss: 1.5605
# Epoch 395/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5415 - val_loss: 1.5767
# Epoch 396/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3046 - val_loss: 1.4401
# Epoch 397/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3301 - val_loss: 1.4926
# Epoch 398/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3542 - val_loss: 1.6485
# Epoch 399/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3816 - val_loss: 1.4907
# Epoch 400/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2907 - val_loss: 1.4899
# Epoch 401/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1934 - val_loss: 1.4072
# Epoch 402/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5252 - val_loss: 1.5862
# Epoch 403/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3933 - val_loss: 1.4905
# Epoch 404/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3779 - val_loss: 1.5686
# Epoch 405/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4309 - val_loss: 1.4167
# Epoch 406/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3598 - val_loss: 1.4472
# Epoch 407/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4151 - val_loss: 1.4061
# Epoch 408/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4330 - val_loss: 1.4107
# Epoch 409/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1868 - val_loss: 1.4459
# Epoch 410/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2843 - val_loss: 1.5763
# Epoch 411/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4211 - val_loss: 1.5700
# Epoch 412/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4846 - val_loss: 1.5385
# Epoch 413/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6729 - val_loss: 1.5880
# Epoch 414/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2668 - val_loss: 1.4510
# Epoch 415/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1692 - val_loss: 1.4859
# Epoch 416/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4264 - val_loss: 1.4604
# Epoch 417/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2510 - val_loss: 1.4503
# Epoch 418/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2892 - val_loss: 1.4314
# Epoch 419/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3952 - val_loss: 1.3905
# Epoch 420/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3280 - val_loss: 1.4221
# Epoch 421/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3725 - val_loss: 1.4685
# Epoch 422/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3631 - val_loss: 1.5160
# Epoch 423/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3562 - val_loss: 1.4437
# Epoch 424/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3673 - val_loss: 1.4188
# Epoch 425/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2554 - val_loss: 1.4192
# Epoch 426/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2596 - val_loss: 1.4176
# Epoch 427/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2744 - val_loss: 1.4191
# Epoch 428/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3724 - val_loss: 1.4039
# Epoch 429/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2515 - val_loss: 1.4516
# Epoch 430/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1978 - val_loss: 1.3909
# Epoch 431/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2514 - val_loss: 1.6469
# Epoch 432/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3988 - val_loss: 1.6134
# Epoch 433/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3365 - val_loss: 1.3960
# Epoch 434/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3949 - val_loss: 1.6646
# Epoch 435/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2905 - val_loss: 1.4288
# Epoch 436/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4367 - val_loss: 1.5014
# Epoch 437/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3818 - val_loss: 1.5661
# Epoch 438/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2700 - val_loss: 1.4294
# Epoch 439/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2468 - val_loss: 1.5548
# Epoch 440/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3381 - val_loss: 1.5487
# Epoch 441/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2169 - val_loss: 1.4190
# Epoch 442/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3124 - val_loss: 1.4168
# Epoch 443/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2641 - val_loss: 1.4840
# Epoch 444/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3630 - val_loss: 1.4048
# Epoch 445/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1853 - val_loss: 1.4347
# Epoch 446/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3115 - val_loss: 1.5626
# Epoch 447/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2627 - val_loss: 1.6557
# Epoch 448/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3310 - val_loss: 1.4297
# Epoch 449/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1978 - val_loss: 1.5098
# Epoch 450/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3134 - val_loss: 1.3994
# Epoch 451/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1752 - val_loss: 1.4109
# Epoch 452/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3011 - val_loss: 1.6221
# Epoch 453/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4391 - val_loss: 1.4378
# Epoch 454/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2109 - val_loss: 1.4520
# Epoch 455/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2537 - val_loss: 1.4233
# Epoch 456/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2257 - val_loss: 1.3961
# Epoch 457/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2513 - val_loss: 1.4087
# Epoch 458/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2559 - val_loss: 1.4181
# Epoch 459/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4011 - val_loss: 1.4614
# Epoch 460/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3010 - val_loss: 1.4068
# Epoch 461/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3908 - val_loss: 1.4460
# Epoch 462/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2386 - val_loss: 1.4535
# Epoch 463/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3352 - val_loss: 1.4971
# Epoch 464/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2865 - val_loss: 1.4174
# Epoch 465/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1981 - val_loss: 1.4446
# Epoch 466/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1794 - val_loss: 1.4503
# Epoch 467/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2811 - val_loss: 1.4658
# Epoch 468/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2221 - val_loss: 1.4592
# Epoch 469/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2103 - val_loss: 1.4547
# Epoch 470/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1753 - val_loss: 1.4592
# Epoch 471/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2277 - val_loss: 1.4253
# Epoch 472/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1406 - val_loss: 1.5089
# Epoch 473/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2066 - val_loss: 1.5961
# Epoch 474/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3829 - val_loss: 1.6372
# Epoch 475/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4533 - val_loss: 1.4939
# Epoch 476/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3172 - val_loss: 1.4165
# Epoch 477/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3286 - val_loss: 1.3645
# Epoch 478/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1952 - val_loss: 1.3817
# Epoch 479/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1743 - val_loss: 1.4750
# Epoch 480/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2343 - val_loss: 1.4337
# Epoch 481/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3618 - val_loss: 1.4113
# Epoch 482/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3253 - val_loss: 1.6321
# Epoch 483/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4022 - val_loss: 1.4012
# Epoch 484/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3215 - val_loss: 1.8571
# Epoch 485/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5296 - val_loss: 1.3584
# Epoch 486/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2446 - val_loss: 1.4116
# Epoch 487/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2786 - val_loss: 1.5094
# Epoch 488/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3833 - val_loss: 1.3920
# Epoch 489/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1529 - val_loss: 1.4475
# Epoch 490/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3293 - val_loss: 1.3815
# Epoch 491/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3076 - val_loss: 1.3981
# Epoch 492/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1886 - val_loss: 1.4711
# Epoch 493/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3113 - val_loss: 1.4048
# Epoch 494/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2132 - val_loss: 1.4963
# Epoch 495/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2328 - val_loss: 1.5389
# Epoch 496/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3239 - val_loss: 1.4028
# Epoch 497/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3376 - val_loss: 1.4455
# Epoch 498/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2282 - val_loss: 1.5225
# Epoch 499/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3705 - val_loss: 1.4586
# Epoch 500/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3507 - val_loss: 1.4124
# Shape of X_test: (320, 85)

# %%
# Predict the test set results
y_pred_nn = model.predict(X_test)

# No need to reshape y_pred_nn


mae_nn = mean_absolute_error(y_test, y_pred_nn)
mse_nn = mean_squared_error(y_test, y_pred_nn)
rmse_nn = np.sqrt(mse_nn)
medae_nn = median_absolute_error(y_test, y_pred_nn)
 
evs_nn = explained_variance_score(y_test, y_pred_nn)

print("Neural Network Metrics:")
print(f"MAE: {mae_nn}, MSE: {mse_nn}, RMSE: {rmse_nn}, MedAE: {medae_nn}, EVS: {evs_nn}\n")
def nse(y_true, y_pred):
    y_true = y_true.values.ravel().astype(float)
    y_pred = y_pred.ravel().astype(float)
    return 1 - np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2)

# Calculate NSE for the model
nse_nn = nse(y_test, y_pred_nn)

print(f"Neural Network NSE: {nse_nn}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Neural Network Metrics:
# MAE: 1.8323520421981812, MSE: 9.18956184387207, RMSE: 3.031429010198337, MedAE: 1.1724805116653436, EVS: 0.9836947615312565
#
# Neural Network NSE: 0.9835887967327657

# %% [markdown]
# Adding graphs.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the width of the bars
barWidth = 0.15

# Assuming you have these metrics for each model
metrics = {
    'Gradient Boosting': {'MAE': mae_gb, 'MSE': mse_gb, 'RMSE': rmse_gb, 'MedAE': medae_gb, 'EVS': evs_gb},
    'RandomForest': {'MAE': mae_rf, 'MSE': mse_rf, 'RMSE': rmse_rf, 'MedAE': medae_rf, 'EVS': evs_rf},
    'Neural Network': {'MAE': mae_nn, 'MSE': mse_nn, 'RMSE': rmse_nn, 'MedAE': medae_nn, 'EVS': evs_nn}
}

# Restructure the data
metrics_by_model = {
    'MAE': {model: metrics[model]['MAE'] for model in metrics},
    'MSE': {model: metrics[model]['MSE'] for model in metrics},
    'RMSE': {model: metrics[model]['RMSE'] for model in metrics},
    'MedAE': {model: metrics[model]['MedAE'] for model in metrics},
    'EVS': {model: metrics[model]['EVS'] for model in metrics},
}

# Set position of bar on X axis
r1 = np.arange(len(metrics_by_model))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.figure(figsize=(12, 8))

# Make the plot
colors = ['b', 'r', 'g', 'y', 'm', 'c']  # Add more colors if needed
for i, model in enumerate(metrics):
    plt.bar([r + i*barWidth for r in r1], list(metrics[model].values()), color=colors[i % len(colors)], width=barWidth, edgecolor='grey', label=model)

# Adding xticks
plt.xlabel('Metrics', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(metrics_by_model))], [metric for metric in metrics_by_model])
plt.legend()
plt.grid()
plt.show()
